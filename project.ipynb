# %%
## About the Data
#I AM USING THE DATA FROM PREVIOUS ASSIGNMENT 

1. Name / Title: NYPD Hate Crimes
2. Link to Data: https://data.cityofnewyork.us/Public-Safety/NYPD-Hate-Crimes/bqiq-cu78 
3. Source / Origin: 
	* Author or Creator: Police Department (NYPD)
	* Publication Date: October 29, 2020
	* Publisher: NYC OpenData
	* Version or Data Accessed: February 22, 2021
4. License: https://opendata.cityofnewyork.us/overview/ 
https://www1.nyc.gov/home/terms-of-use.page
# Out:
#   File "<ipython-input-2-08c4c0821878>", line 4
#     1. Name / Title: NYPD Hate Crimes
#        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/NYPD_Hate_Crimes.csv')
df.head(4)
df.dtypes
# Out:
# Full Complaint ID                 int64
# Complaint Year Number             int64
# Month Number                      int64
# Record Create Date               object
# Complaint Precinct Code           int64
# Patrol Borough Name              object
# County                           object
# Law Code Category Description    object
# Offense Description              object
# PD Code Description              object
# Bias Motive Description          object
# Offense Category                 object
# Other Motive Description         object
# Arrest Date                      object
# Arrest Id                        object
# dtype: object

# %%
df.head(4)
# Out:
#    Full Complaint ID  Complaint Year Number  Month Number Record Create Date  \
# 0    201904600132799                   2019             2         02/08/2019
# 1    201904800157499                   2019             3         03/09/2019
# 2    201904800154599                   2019             3         03/08/2019
# 3    201904800159299                   2019             3         03/10/2019
#
#    Complaint Precinct Code Patrol Borough Name County  \
# 0                       46   PATROL BORO BRONX  BRONX
# 1                       48   PATROL BORO BRONX  BRONX
# 2                       48   PATROL BORO BRONX  BRONX
# 3                       48   PATROL BORO BRONX  BRONX
#
#   Law Code Category Description           Offense Description  \
# 0                        FELONY                FELONY ASSAULT
# 1                   MISDEMEANOR  ASSAULT 3 & RELATED OFFENSES
# 2                   MISDEMEANOR  ASSAULT 3 & RELATED OFFENSES
# ...

# %%
# FILL MISSING DATA 
df.fillna(0)
# Out:
#      Full Complaint ID  Complaint Year Number  Month Number  \
# 0      201904600132799                   2019             2
# 1      201904800157499                   2019             3
# 2      201904800154599                   2019             3
# 3      201904800159299                   2019             3
# 4      201904200333499                   2019             5
# ..                 ...                    ...           ...
# 723    202012000530199                   2020             9
# 724    202012100298499                   2020             6
# 725    202012200273399                   2020             7
# 726    202012200278999                   2020             6
# 727    202012300167999                   2020             8
#
#     Record Create Date  Complaint Precinct Code        Patrol Borough Name  \
# 0           02/08/2019                       46          PATROL BORO BRONX
# 1           03/09/2019                       48          PATROL BORO BRONX
# ...

# %%
#value_counts for anti-asian in 2019 and 2020
df.groupby(["Bias Motive Description"]).count()
#we can see 31
# Out:
#                                    Full Complaint ID  Complaint Year Number  \
# Bias Motive Description
# 50 YEARS OLD OR MORE                               1                      1
# ANTI-ARAB                                          6                      6
# ANTI-ASIAN                                        31                     31
# ANTI-BLACK                                        75                     75
# ANTI-BUDDHIST                                      2                      2
# ANTI-CATHOLIC                                     15                     15
# ANTI-FEMALE                                       11                     11
# ANTI-FEMALE HOMOSEXUAL(GAY)                       11                     11
# ANTI-GENDER NON CONFORMING                         2                      2
# ANTI-HINDU                                         2                      2
# ANTI-HISPANIC                                      9                      9
# ...

# %%
#visualization of anti-white anti-black and anti-asian 
import matplotlib.pyplot as plt
import numpy as np
df2 = pd.DataFrame(np.array([[38, 75, 31]]), columns=["anti-white", "anti-black", "anti-asian"])

df2.plot.bar()

# %%
#if/else felony create new column
df['if/else felony'] = np.where(df['Law Code Category Description']== 'FELONY', True, False)
df.head(3)
# Out:
#    Full Complaint ID  Complaint Year Number  Month Number Record Create Date  \
# 0    201904600132799                   2019             2         02/08/2019
# 1    201904800157499                   2019             3         03/09/2019
# 2    201904800154599                   2019             3         03/08/2019
#
#    Complaint Precinct Code Patrol Borough Name County  \
# 0                       46   PATROL BORO BRONX  BRONX
# 1                       48   PATROL BORO BRONX  BRONX
# 2                       48   PATROL BORO BRONX  BRONX
#
#   Law Code Category Description           Offense Description  \
# 0                        FELONY                FELONY ASSAULT
# 1                   MISDEMEANOR  ASSAULT 3 & RELATED OFFENSES
# 2                   MISDEMEANOR  ASSAULT 3 & RELATED OFFENSES
#
#         PD Code Description    Bias Motive Description    Offense Category  \
# 0  ASSAULT 2,1,UNCLASSIFIED  ANTI-MALE HOMOSEXUAL(GAY)  Sexual Orientation
# ...

# %%
# I did four of the pandas usage:
#first fill in miss values; second create a new column; third visualization; fourth value counts
